# %%
import torch 
import torch.nn as nn

# %%
nn.Embedding??
# Out:
# Init signature:
# nn.Embedding(
#     num_embeddings: int,
#     embedding_dim: int,
#     padding_idx: Optional[int] = None,
#     max_norm: Optional[float] = None,
#     norm_type: float = 2.0,
#     scale_grad_by_freq: bool = False,
#     sparse: bool = False,
#     _weight: Optional[torch.Tensor] = None,
#     _freeze: bool = False,
#     device=None,
#     dtype=None,
# ) -> None
# Source:
# class Embedding(Module):
#     r"""A simple lookup table that stores embeddings of a fixed dictionary and size.
#
#     This module is often used to store word embeddings and retrieve them using indices.
#     The input to the module is a list of indices, and the output is the corresponding
#     word embeddings.
#
#     Args:
#         num_embeddings (int): size of the dictionary of embeddings
#         embedding_dim (int): the size of each embedding vector
#         padding_idx (int, optional): If specified, the entries at :attr:`padding_idx` do not contribute to the gradient;
# ...

# %%
d_model = 10
vocab_size = 6
input_embeddings = nn.Embedding(vocab_size, d_model)
input_embeddings
# Out:
# Embedding(6, 10)

# %%
input_embeddings.weight
# Out:
# Parameter containing:
# tensor([[-1.1261, -0.6685,  0.6189, -0.3667, -0.2105,  1.4254, -1.1563, -1.0856,
#           0.2040,  1.5185],
#         [-0.1961, -0.5574, -0.8825, -0.9039, -0.9860, -0.8786, -0.8114, -0.0213,
#          -0.8475, -0.3802],
#         [ 0.7410,  0.0326, -0.2902, -1.3643, -0.6861,  0.0643, -0.5170, -1.5300,
#          -1.2576,  0.1207],
#         [ 0.8669, -0.4737,  1.2615, -1.3752,  2.0684,  1.4426,  0.1616,  0.1236,
#           0.4071,  1.2241],
#         [ 0.8022, -1.2100, -1.0765,  0.2297,  1.4400, -1.0070, -0.3758,  0.8113,
#           0.4584, -0.6649],
#         [-0.4316,  0.4154,  0.8078, -0.0154,  1.2916, -0.3710, -0.4888,  0.5559,
#          -0.2423,  1.3179]], requires_grad=True)
